# %% [markdown]
# # Kruskal-Wallis Test
#
# Non-parametric alternative to one-way ANOVA.
#
# Used for comparing three or more independent groups.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

sns.set_style("whitegrid")
sns.set_context("talk")

plt.rcParams['figure.figsize'] = (10,6)

# %%
from scipy.stats import kruskal

group1=[70,72,75,78]

group2=[65,68,70,72]

group3=[80,82,85,88]

# %%
statistic,p_value=kruskal(
    group1,
    group2,
    group3
)

print("Statistic =",round(statistic,3))

print("P-value =",round(p_value,5))
# Out:
# Statistic = 8.831
# P-value = 0.01209

# %%
alpha=0.05

if p_value<alpha:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# Reject H0

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=[group1,group2,group3]
)

plt.xticks(
    [0,1,2],
    ['Group1','Group2','Group3']
)

plt.title("Kruskal-Wallis Comparison")

plt.show()

# %% [markdown]
# # Conclusion
#
# Kruskal-Wallis compares multiple groups when normality assumption is violated.
